# %%
import argparse
import torch
from torch_geometric.data import DataLoader
#import models_ggnn_oldpipe as models
import models_fastsim as models
import utils
import matplotlib
from copy import deepcopy
import os
import copy
import uproot
import awkward as ak
import xgboost as xgb

#matplotlib.use("pdf")
import numpy as np
import random
import pickle
import joblib
from timeit import default_timer as timer
from tqdm import tqdm

import matplotlib as mpl
import imageio

#mpl.use("pdf")
import matplotlib.pyplot as plt
import mplhep as hep

hep.set_style(hep.style.CMS)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())

from pyjet import cluster, DTYPE_PTEPM
from collections import OrderedDict
import scipy.stats
# Out:
# True
# /depot/cms/private/users/gpaspala/miniconda3/envs/DeepPuppi/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /tmp/ipykernel_3746216/3901455568.py:30: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style(hep.style.CMS)

# %%
#open with uproot to get the gen info:
# read the ttree
tree = uproot.open("/depot/cms/private/users/gpaspala/output_1.root")["Events"]
# read the pf candidates and gen particle information into akward arrays
pfcands = tree.arrays(tree.keys('PF_*') + ['nPF'], entry_start=0, entry_stop=100)
genparts = tree.arrays(tree.keys('packedGenPart_*') + ['npackedGenPart'], entry_start=0, entry_stop=100)

# %%
isGenChg = genparts['packedGenPart_charge']!=0

# %%
def deltaPhiNew(dphis):
    dphis = np.where(dphis > np.pi, dphis - 2*np.pi, dphis)
    dphis = np.where(dphis <-np.pi, dphis + 2*np.pi, dphis)
    return dphis

def deltaRNew(detas, dphis):
    """
    calculate the deltaR based on the input deta and phi
    """
    dphis = deltaPhiNew(dphis)
    dR = np.sqrt(detas**2 + dphis**2)
    return dR

# %% [markdown]
# Load the model

# %%
class Args(object):
    def __init__(self, model_type = 'Gated', do_boost=False, extralayers=False):
        self.model_type = model_type
        self.num_layers = 2
        self.batch_size = 1
        self.hidden_dim = 20
        self.dropout = 0
        self.opt = 'adam'
        self.weight_decay = 0
        self.lr = 0.01
        self.do_boost = do_boost
        self.extralayers = extralayers

# %%
args = Args()

# %%
class PerformanceMetrics(object):
    def __init__(self):
        pt = 0.
        pt_diff = 0.
        mass_diff = 0.
        dR_diff = 0.

# %%
def generate_mask(dataset):
    # how many LV and PU to sample
    # dataset = deepcopy(dataset_org)
    for graph in dataset:
        LV_index = graph.LV_index
        PU_index = graph.PU_index
        original_feature = graph.x[:, 0:graph.num_feature_actual]

        num_select_LV = 10
        num_select_PU = 160

        if LV_index.shape[0] < num_select_LV or PU_index.shape[0] < num_select_PU:
            num_select_LV = min(LV_index.shape[0], num_select_LV)
            num_select_PU = min(PU_index.shape[0], num_select_PU)

        # generate the index for LV and PU samples for training mask
        gen_index_LV = random.sample(range(LV_index.shape[0]), num_select_LV)
        selected_LV_train = LV_index[gen_index_LV]

        gen_index_PU = random.sample(range(PU_index.shape[0]), num_select_PU)
        selected_PU_train = PU_index[gen_index_PU]

        training_mask = np.concatenate((selected_LV_train, selected_PU_train), axis=None)
        #print(training_mask)

        # construct mask vector for training and testing
        mask_training = torch.zeros(graph.num_nodes, 1)
        mask_training[[training_mask.tolist()]] = 1

        x_concat = torch.cat((original_feature, mask_training), 1)
        graph.x = x_concat

        
        # mask the puppiWeight as default Neutral(here puppiweight is actually fromLV in ggnn dataset)
        puppiWeight_default_one_hot_training = torch.cat((torch.zeros(graph.num_nodes, 1),
                                                          torch.zeros(graph.num_nodes, 1),
                                                          torch.ones(graph.num_nodes, 1)), 1)
        puppiWeight_default_one_hot_training = puppiWeight_default_one_hot_training.type(torch.float32)
        
        #mask the pdgID for charge particles
        pdgId_one_hot_training = torch.cat((torch.zeros(graph.num_nodes, 1),
                                                          torch.zeros(graph.num_nodes, 1),
                                                          torch.ones(graph.num_nodes, 1)), 1)       
        pdgId_one_hot_training = pdgId_one_hot_training.type(torch.float32)

        pf_dz_training_test=torch.clone(original_feature[:,6:7])
        pf_dz_training_test = torch.zeros(graph.num_nodes, 1)    
        

        # -4 is for one hot encoding of fromLV and one mask; -1 is for final puppiweight
        #default_data_training = torch.cat(
         #   (original_feature[:, 0:(graph.num_features - 4 - 1)], puppiWeight_default_one_hot_training,
         #    original_feature[:, -1].view(-1, 1)), 1)
        default_data_training = torch.cat(
             (original_feature[:, 0:(graph.num_feature_actual - 7)],pdgId_one_hot_training, pf_dz_training_test ,puppiWeight_default_one_hot_training), 1)
        

        concat_default = torch.cat((graph.x, default_data_training), 1)
        graph.x = concat_default

# %%
def test(filelists, models={}):
    
    for model in models.values():
        model.to('cuda:0')
        model.eval()
    
    performances_jet_puppi = []
    performances_jet_puppi_wcut = []
    
    mets_truth = []
    mets_puppi = []
    mets_puppi_wcut = []
    
    performances_jet_pred = OrderedDict()
    mets_pred = OrderedDict()
    for modelname in models.keys():
        performances_jet_pred[modelname] = []
        mets_pred[modelname] = []
    
    ievt = 0
    for ifile in filelists:
        print("ifile: ", ifile)
        fp = open(ifile, "rb")
        dataset = joblib.load(fp)
        generate_neu_mask(dataset)
        generate_mask(dataset)
        data = DataLoader(dataset, batch_size=1)
        loader = data
        
        for data in loader:
            ievt += 1
            #if ievt > 10:
            #    break
            
            if ievt%10 == 0:
                print("processed {} events".format(ievt))
            with torch.no_grad():
                data = data.to(device)
                # max(dim=1) returns values, indices tuple; only need indices
                
                # loop over model in models and run the inference
                preds = []

                for model in models.values():
                    model.to('cuda:0')
                    model.eval()
                    
                    pred = model.forward(data)
                    #print("pred here: ", pred)
                    preds.append(pred)
            
                #met_truth, perfs_jet_puppi, met_puppi, perfs_jet_puppi_wcut, met_puppi_wcut, perfs_jet_pred, mets_fromF_pred = postProcessing(data, preds)
                met_truth,perfs_jet_pred, mets_fromF_pred = postProcessing(data, preds, ievt)
                #perfs_jet_puppi, perfs_jet_puppi_wcut, perfs_jet_pred, perfs_jet_pred2, met_truth, met_puppi, met_puppi_wcut, met_pred, met_pred2 = postProcessing(data, preds)
            
                
                
                imodel = 0
                for modelname in models.keys():
                    #print("modelname ", perfs_jet_pred[imodel])
                    #print("performances_jet_pred modelname", performances_jet_pred[modelname] )
                    performances_jet_pred[modelname] += perfs_jet_pred[imodel]
                    mets_pred[modelname].append(mets_fromF_pred[imodel])
                    imodel += 1
                
        fp.close()


    return mets_truth, performances_jet_pred, mets_pred

# %%
def generate_neu_mask(dataset):
    # all neutrals with pt cuts are masked for evaluation
    for graph in dataset:
        nparticles = graph.num_nodes
        graph.num_feature_actual = graph.num_features
        Neutral_index = graph.Neutral_index
        Neutral_feature = graph.x[Neutral_index]
        Neutral_index = Neutral_index[torch.where(Neutral_feature[:, 2] > 0.5)[0]]

        mask_neu = torch.zeros(nparticles, 1)
        mask_neu[Neutral_index, 0] = 1
        graph.mask_neu = mask_neu

    return dataset

# %%
def clusterJets(pt, eta, phi, ptcut=0., deltaR=0.7):
    """
    cluster the jets based on the array of pt, eta, phi,
    of all particles (masses are assumed to be zero),
    with pyjet clustering algo
    """
    # cleaning zero pt-ed objects
    pt_wptcut   = pt[pt > ptcut]
    eta_wptcut  = eta[pt > ptcut]
    phi_wptcut  = phi[pt > ptcut]
    mass_wptcut = np.zeros(pt_wptcut.shape[0])
    
    event = np.column_stack((pt_wptcut, eta_wptcut, phi_wptcut, mass_wptcut))
    event.dtype = DTYPE_PTEPM
    sequence = cluster(event, R=deltaR, p=-1)
    jets = sequence.inclusive_jets(ptmin=30)
    
    print ("done")
    
    return jets

def deltaPhi(phi1, phi2):
    dphi = phi1 - phi2
    while dphi > np.pi:
        dphi -= 2 * np.pi
    while dphi < -np.pi:
        dphi += 2 * np.pi
    return dphi

def deltaR(eta1, phi1, eta2, phi2):
    """
    calculate the deltaR between two jets/particles
    """
    deta = eta1 - eta2
    dphi = phi1 - phi2
    while dphi > np.pi:
        dphi -= 2 * np.pi
    while dphi < -np.pi:
        dphi += 2 * np.pi
    return np.hypot(deta, dphi)

def deltaRJet(jet1, jet2):
    """
    calculate the deltaR of the two PseudoJet
    """
    return deltaR(jet1.eta, jet1.phi, jet2.eta, jet2.phi)

def matchJets(jets_truth, jets_reco, dRcut=0.1):
    """
    match the jets in jets_reco to jets_truth,
    based on the deltaR
    """
    matched_indices = []
    
    jets_truth_indices = list(range(len(jets_truth)))
    jets_reco_indices  = list(range(len(jets_reco)))
    
    for ijet_reco in jets_reco_indices:
        for ijet_truth in jets_truth_indices:
            #print("deltR between {} and {} is {}".format(ijet_truth, ijet_reco, deltaRJet(jets_truth[ijet_truth], jets_reco[ijet_reco])))
            if deltaRJet(jets_truth[ijet_truth], jets_reco[ijet_reco]) < dRcut:
                matched_indices.append((ijet_truth, ijet_reco))
                jets_truth_indices.remove(ijet_truth)
                break
    
    return matched_indices

def compareJets(jets_truth, jets_reco, dRcut=0.1):
    """
    match jets between truth and reco using matchJets,
    and then compared the matched deltaR, pt, and mass
    """
    performances = []
    
    matched_indices = matchJets(jets_truth, jets_reco, dRcut=dRcut)
    for ijet_truth, ijet_reco in matched_indices:
        perf = PerformanceMetrics()
        perf.pt_truth = jets_truth[ijet_truth].pt
        perf.mass_diff =  (jets_reco[ijet_reco].mass - jets_truth[ijet_truth].mass)/(jets_truth[ijet_truth].mass+1e-6)
        perf.pt_diff   =  (jets_reco[ijet_reco].pt   - jets_truth[ijet_truth].pt)/(jets_truth[ijet_truth].pt+1e-6)
        perf.dR_diff   =  deltaRJet(jets_truth[ijet_truth], jets_reco[ijet_reco])
        performances.append(perf)
    return performances

def calculateMET(pt, phi):
    """
    calculate the MET based on all particles pt and phi
    """
    met_x = np.sum(pt * np.cos(phi), axis=0)
    met_y = np.sum(pt * np.sin(phi), axis=0)
    return np.hypot(met_x, met_y)

# %%
def postProcessing(data, preds, ievt):
   
    pt = ak.to_numpy(genparts['packedGenPart_pt'][ievt])
    eta= ak.to_numpy(genparts['packedGenPart_eta'][ievt])
    phi= ak.to_numpy(genparts['packedGenPart_phi'][ievt])
    mass=ak.to_numpy(genparts['packedGenPart_mass'][ievt])
    truth = np.array(data.y.cpu().detach()) 
    
       
    pt[pt<0.5]=0
    #print (pt)
    
    # cluster jets with gen particles
    jets_clustered = clusterJets(pt, eta, phi, mass)

    print (jets_clustered)
    
    # calculate MET and compare
    met_truth = calculateMET(pt, phi)
    
    #print (met_truth)
    
  # evaluate the performances for the predictions
    performances_jet_pred = []
    mets_pred = []
    
    for pred in preds:
        #print("preds: ", pred)
        pred = np.array(pred[0][:,0].cpu().detach())
        
        # apply CHS to predictions
        charge_index = data.Charge_index[0]
        pred[charge_index] = truth[charge_index]
        
        pt_pred = pt * pred[0]
        jets_pred  = clusterJets(pt_pred,  eta, phi)
        performance_jet_pred = compareJets(jets_clustered, jets_pred)
        
        # MET
        met_pred  = calculateMET(pt_pred,  phi)
        
        performances_jet_pred.append( performance_jet_pred )
        mets_pred.append( met_pred )

    return met_truth, performances_jet_pred, mets_pred

# %%
filelists = ["/home/gpaspala/new_Pileup_GNN/Pileup_GNN/datasets/dataset_graph_puppi_100"]

# %%
ifile = "/home/gpaspala/new_Pileup_GNN/Pileup_GNN/datasets/dataset_graph_puppi_100"
fp = open(ifile, "rb")
dataset = joblib.load(fp)

# %%
model_gated_boost = models.GNNStack(10, args.hidden_dim, 1, args)
#model_load.load_state_dict(torch.load('best_valid_model_semi.pt'))
model_gated_boost.load_state_dict(torch.load('/home/gpaspala/new_Pileup_GNN/Pileup_GNN/fast_simulation/test/best_valid_model.pt'))
# Out:
# <All keys matched successfully>

# %%
modelcolls = OrderedDict()
modelcolls['gated_boost'] = model_gated_boost

# %%
mets_truth, performances_jet_pred, mets_pred = test(filelists, modelcolls)
# Out:
# ifile:  /home/gpaspala/new_Pileup_GNN/Pileup_GNN/datasets/dataset_graph_puppi_100
# done
# [PseudoJet(pt=75.997, eta=-1.766, phi=-0.011, mass=13.692), PseudoJet(pt=57.592, eta=0.024, phi=2.659, mass=10.293)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=41.122, eta=-4.076, phi=2.739, mass=13.201), PseudoJet(pt=32.358, eta=-0.319, phi=-0.278, mass=7.009)]
# done
# done
# [PseudoJet(pt=31.331, eta=-0.776, phi=0.292, mass=5.324)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=43.257, eta=3.212, phi=-0.710, mass=13.772), PseudoJet(pt=41.775, eta=3.689, phi=2.364, mass=8.492)]
# done
# done
# [PseudoJet(pt=30.056, eta=-2.038, phi=-1.405, mass=6.976)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=169.185, eta=1.385, phi=1.285, mass=32.597), PseudoJet(pt=160.244, eta=0.767, phi=-1.802, mass=32.945)]
# done
# processed 10 events
# done
# [PseudoJet(pt=96.169, eta=1.872, phi=2.925, mass=8.329), PseudoJet(pt=90.021, eta=1.588, phi=-0.219, mass=13.051)]
# done
# done
# [PseudoJet(pt=46.643, eta=0.957, phi=-0.294, mass=14.713)]
# done
# done
# [PseudoJet(pt=175.965, eta=1.036, phi=-1.870, mass=32.745), PseudoJet(pt=155.711, eta=-0.785, phi=1.825, mass=33.499), PseudoJet(pt=84.983, eta=4.223, phi=0.001, mass=8.431)]
# done
# done
# [PseudoJet(pt=538.387, eta=1.063, phi=-0.595, mass=42.828), PseudoJet(pt=524.413, eta=0.412, phi=2.606, mass=23.620)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=37.361, eta=-2.497, phi=-0.613, mass=3.811), PseudoJet(pt=36.842, eta=0.756, phi=3.059, mass=6.786)]
# done
# done
# [PseudoJet(pt=91.535, eta=1.115, phi=-0.770, mass=26.807), PseudoJet(pt=76.636, eta=-0.241, phi=-2.624, mass=16.773), PseudoJet(pt=76.573, eta=2.087, phi=1.623, mass=7.587), PseudoJet(pt=32.620, eta=-1.205, phi=2.677, mass=7.405)]
# done
# done
# [PseudoJet(pt=428.240, eta=-1.094, phi=0.920, mass=34.751), PseudoJet(pt=419.014, eta=-1.567, phi=-2.206, mass=75.338)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=987.142, eta=-0.191, phi=-0.997, mass=129.359), PseudoJet(pt=951.804, eta=0.190, phi=2.264, mass=123.202), PseudoJet(pt=130.901, eta=-0.066, phi=1.086, mass=30.942)]
# done
# processed 20 events
# done
# [PseudoJet(pt=196.442, eta=-2.460, phi=-0.204, mass=36.751), PseudoJet(pt=186.298, eta=-1.820, phi=-2.932, mass=24.333), PseudoJet(pt=58.869, eta=1.542, phi=2.277, mass=12.078), PseudoJet(pt=54.753, eta=-2.203, phi=0.844, mass=4.812)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=164.775, eta=-1.641, phi=0.094, mass=7.864), PseudoJet(pt=163.007, eta=1.913, phi=3.141, mass=13.410)]
# done
# done
# [PseudoJet(pt=379.020, eta=-0.848, phi=0.205, mass=40.164), PseudoJet(pt=219.062, eta=0.496, phi=-3.047, mass=20.431), PseudoJet(pt=110.397, eta=-0.610, phi=-2.601, mass=15.710), PseudoJet(pt=94.386, eta=0.013, phi=-1.786, mass=18.128), PseudoJet(pt=56.967, eta=1.311, phi=1.430, mass=16.630), PseudoJet(pt=55.005, eta=-1.531, phi=2.728, mass=14.709)]
# done
# done
# [PseudoJet(pt=922.333, eta=-1.254, phi=-1.193, mass=39.462), PseudoJet(pt=921.117, eta=-0.789, phi=1.947, mass=38.287)]
# done
# done
# [PseudoJet(pt=550.760, eta=-0.789, phi=2.336, mass=38.641), PseudoJet(pt=389.535, eta=-0.736, phi=-1.026, mass=68.942), PseudoJet(pt=180.522, eta=-1.615, phi=-0.106, mass=58.690), PseudoJet(pt=47.768, eta=3.452, phi=-2.207, mass=8.677)]
# done
# done
# [PseudoJet(pt=70.873, eta=1.672, phi=1.141, mass=14.954), PseudoJet(pt=68.740, eta=-1.043, phi=-1.949, mass=21.500)]
# done
# done
# [PseudoJet(pt=114.608, eta=1.455, phi=-0.782, mass=12.926), PseudoJet(pt=80.240, eta=-1.614, phi=2.367, mass=14.915), PseudoJet(pt=53.553, eta=-0.599, phi=2.382, mass=12.938)]
# done
# done
# [PseudoJet(pt=246.535, eta=0.454, phi=1.593, mass=84.884), PseudoJet(pt=242.771, eta=1.186, phi=-1.523, mass=27.778)]
# done
# done
# [PseudoJet(pt=184.188, eta=-1.057, phi=-1.376, mass=17.335), PseudoJet(pt=159.689, eta=2.615, phi=2.155, mass=20.164), PseudoJet(pt=136.081, eta=0.146, phi=0.635, mass=14.377), PseudoJet(pt=69.839, eta=1.873, phi=2.896, mass=20.461), PseudoJet(pt=42.752, eta=-3.416, phi=-1.484, mass=6.595)]
# done
# processed 30 events
# done
# [PseudoJet(pt=555.350, eta=0.738, phi=2.888, mass=32.447), PseudoJet(pt=500.701, eta=-0.553, phi=-1.306, mass=25.395), PseudoJet(pt=436.093, eta=0.717, phi=1.029, mass=33.127), PseudoJet(pt=174.440, eta=1.485, phi=-0.125, mass=7.434)]
# done
# done
# [PseudoJet(pt=38.886, eta=3.923, phi=-2.619, mass=2.017), PseudoJet(pt=33.480, eta=0.862, phi=0.668, mass=8.534)]
# done
# done
# [PseudoJet(pt=81.211, eta=3.826, phi=-1.441, mass=13.084), PseudoJet(pt=32.016, eta=3.093, phi=1.418, mass=11.596)]
# done
# done
# [PseudoJet(pt=631.646, eta=-1.400, phi=2.401, mass=36.157), PseudoJet(pt=613.966, eta=0.178, phi=-0.883, mass=57.833), PseudoJet(pt=80.396, eta=-0.632, phi=0.746, mass=18.426)]
# done
# done
# [PseudoJet(pt=2286.958, eta=-0.877, phi=0.828, mass=97.707), PseudoJet(pt=2226.943, eta=-0.423, phi=-2.306, mass=298.105), PseudoJet(pt=56.896, eta=0.316, phi=-2.549, mass=7.834)]
# done
# done
# [PseudoJet(pt=77.672, eta=2.976, phi=-3.123, mass=21.233), PseudoJet(pt=63.891, eta=-0.616, phi=0.038, mass=18.862)]
# done
# done
# [PseudoJet(pt=30.888, eta=-1.129, phi=-2.093, mass=8.145)]
# done
# done
# [PseudoJet(pt=85.300, eta=1.967, phi=0.200, mass=16.229), PseudoJet(pt=52.614, eta=-0.779, phi=2.788, mass=12.315), PseudoJet(pt=41.347, eta=-0.973, phi=-2.501, mass=11.585)]
# done
# done
# [PseudoJet(pt=579.397, eta=-0.946, phi=0.123, mass=39.171), PseudoJet(pt=577.214, eta=-1.740, phi=-3.012, mass=28.459)]
# done
# done
# [PseudoJet(pt=2782.666, eta=-0.517, phi=2.420, mass=50.576), PseudoJet(pt=2774.759, eta=0.909, phi=-0.718, mass=322.328)]
# done
# processed 40 events
# done
# [PseudoJet(pt=2356.956, eta=-0.249, phi=-2.169, mass=138.933), PseudoJet(pt=2016.179, eta=-0.291, phi=0.902, mass=311.287), PseudoJet(pt=451.760, eta=0.565, phi=1.262, mass=32.626), PseudoJet(pt=62.407, eta=3.527, phi=-1.703, mass=16.972), PseudoJet(pt=45.932, eta=-2.912, phi=-2.955, mass=11.332)]
# done
# done
# [PseudoJet(pt=2629.735, eta=-0.547, phi=0.082, mass=415.814), PseudoJet(pt=2622.037, eta=-0.496, phi=-3.062, mass=58.592)]
# done
# done
# [PseudoJet(pt=35.730, eta=-0.838, phi=-0.003, mass=5.501)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=854.129, eta=0.081, phi=-0.688, mass=31.594), PseudoJet(pt=822.705, eta=0.849, phi=2.437, mass=100.571)]
# done
# done
# []
# done
# done
# []
# done
# done
# [PseudoJet(pt=111.314, eta=-1.196, phi=1.336, mass=7.238), PseudoJet(pt=89.190, eta=2.572, phi=-1.791, mass=27.958)]
# done
# done
# [PseudoJet(pt=33.106, eta=-0.012, phi=-0.579, mass=5.375)]
# done
# done
# []
# done
# processed 50 events
# done
# [PseudoJet(pt=2529.505, eta=0.289, phi=-0.518, mass=162.748), PseudoJet(pt=2519.962, eta=-0.550, phi=2.629, mass=72.466), PseudoJet(pt=109.143, eta=0.864, phi=1.301, mass=22.493), PseudoJet(pt=61.962, eta=2.965, phi=-1.539, mass=13.916), PseudoJet(pt=41.897, eta=0.691, phi=-2.869, mass=11.396)]
# done
# done
# [PseudoJet(pt=62.426, eta=3.539, phi=0.033, mass=24.160), PseudoJet(pt=57.967, eta=-1.541, phi=3.060, mass=11.208)]
# done
# done
# [PseudoJet(pt=44.689, eta=-2.105, phi=3.040, mass=7.214)]
# done
# done
# [PseudoJet(pt=567.012, eta=-0.228, phi=3.114, mass=40.390), PseudoJet(pt=352.013, eta=1.650, phi=0.134, mass=91.632), PseudoJet(pt=146.135, eta=-0.293, phi=-0.808, mass=26.159), PseudoJet(pt=82.503, eta=0.861, phi=0.893, mass=11.438), PseudoJet(pt=73.126, eta=0.959, phi=-0.359, mass=26.482)]
# done
# done
# [PseudoJet(pt=3417.097, eta=-0.016, phi=1.218, mass=133.310), PseudoJet(pt=3388.898, eta=0.250, phi=-1.931, mass=27.713), PseudoJet(pt=39.329, eta=-1.898, phi=-0.962, mass=8.992)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=220.247, eta=2.051, phi=-2.778, mass=24.715), PseudoJet(pt=188.819, eta=0.100, phi=0.613, mass=25.764), PseudoJet(pt=66.133, eta=0.296, phi=-0.143, mass=8.092)]
# done
# done
# [PseudoJet(pt=3560.652, eta=0.725, phi=-0.688, mass=92.397), PseudoJet(pt=3488.389, eta=0.057, phi=2.474, mass=271.634), PseudoJet(pt=107.124, eta=-2.231, phi=1.710, mass=16.509)]
# done
# done
# [PseudoJet(pt=1487.994, eta=-0.615, phi=2.842, mass=72.436), PseudoJet(pt=1474.736, eta=-0.034, phi=-0.322, mass=239.170), PseudoJet(pt=32.790, eta=-1.507, phi=1.820, mass=5.601)]
# done
# done
# [PseudoJet(pt=333.890, eta=-0.953, phi=1.784, mass=55.837), PseudoJet(pt=263.770, eta=0.827, phi=-1.324, mass=73.537), PseudoJet(pt=48.064, eta=-0.004, phi=-1.204, mass=12.031)]
# done
# processed 60 events
# done
# [PseudoJet(pt=42.939, eta=-1.380, phi=-1.208, mass=6.401), PseudoJet(pt=31.265, eta=-1.298, phi=1.954, mass=6.852)]
# done
# done
# [PseudoJet(pt=194.255, eta=2.623, phi=1.773, mass=32.028), PseudoJet(pt=183.332, eta=2.280, phi=-1.386, mass=21.421)]
# done
# done
# [PseudoJet(pt=2452.027, eta=0.488, phi=-0.752, mass=74.116), PseudoJet(pt=2294.428, eta=-0.229, phi=2.304, mass=410.077), PseudoJet(pt=121.110, eta=-0.474, phi=-2.681, mass=22.535), PseudoJet(pt=103.561, eta=-3.242, phi=3.139, mass=25.610), PseudoJet(pt=46.267, eta=-0.583, phi=1.608, mass=8.182)]
# done
# done
# [PseudoJet(pt=60.449, eta=1.094, phi=1.714, mass=11.830), PseudoJet(pt=55.490, eta=-0.417, phi=-1.375, mass=14.665)]
# done
# done
# [PseudoJet(pt=135.056, eta=0.282, phi=-1.904, mass=28.696), PseudoJet(pt=121.919, eta=1.647, phi=1.206, mass=22.345)]
# done
# done
# [PseudoJet(pt=397.928, eta=-0.776, phi=3.058, mass=56.443), PseudoJet(pt=289.179, eta=-0.336, phi=0.038, mass=39.154), PseudoJet(pt=98.045, eta=1.047, phi=-0.517, mass=21.606), PseudoJet(pt=40.197, eta=1.917, phi=0.039, mass=12.833)]
# done
# done
# [PseudoJet(pt=3479.956, eta=-0.069, phi=-1.589, mass=221.063), PseudoJet(pt=3478.579, eta=-0.038, phi=1.555, mass=345.518)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=1627.842, eta=-0.288, phi=1.961, mass=40.253), PseudoJet(pt=1475.091, eta=-0.327, phi=-1.099, mass=93.159), PseudoJet(pt=173.653, eta=0.152, phi=-1.863, mass=14.364)]
# done
# done
# [PseudoJet(pt=94.913, eta=-0.793, phi=0.765, mass=22.983), PseudoJet(pt=56.353, eta=2.359, phi=-2.403, mass=19.869)]
# done
# processed 70 events
# done
# [PseudoJet(pt=74.439, eta=0.575, phi=-1.822, mass=18.971), PseudoJet(pt=55.630, eta=1.622, phi=1.859, mass=11.979)]
# done
# done
# [PseudoJet(pt=65.792, eta=-0.310, phi=-2.181, mass=12.260), PseudoJet(pt=56.598, eta=-3.032, phi=0.806, mass=8.012)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=56.306, eta=-0.850, phi=2.603, mass=9.891), PseudoJet(pt=47.149, eta=-2.789, phi=-0.448, mass=8.925)]
# done
# done
# [PseudoJet(pt=194.817, eta=-2.266, phi=0.685, mass=46.867), PseudoJet(pt=156.012, eta=-1.568, phi=-2.371, mass=14.406), PseudoJet(pt=34.372, eta=0.577, phi=-2.170, mass=8.921)]
# done
# done
# [PseudoJet(pt=600.336, eta=1.814, phi=-1.233, mass=31.312), PseudoJet(pt=364.502, eta=0.879, phi=1.737, mass=21.702), PseudoJet(pt=307.689, eta=-0.036, phi=1.865, mass=27.690), PseudoJet(pt=64.290, eta=2.329, phi=-1.863, mass=2.772), PseudoJet(pt=57.492, eta=-3.937, phi=-2.335, mass=2.651)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=87.484, eta=-1.308, phi=0.298, mass=12.835), PseudoJet(pt=46.794, eta=-1.396, phi=-2.990, mass=8.496), PseudoJet(pt=43.131, eta=-3.236, phi=-2.697, mass=13.368)]
# done
# done
# [PseudoJet(pt=298.744, eta=-0.539, phi=2.504, mass=29.643), PseudoJet(pt=297.079, eta=-1.551, phi=-0.656, mass=34.224)]
# done
# done
# [PseudoJet(pt=36.078, eta=2.114, phi=1.403, mass=6.278), PseudoJet(pt=31.581, eta=3.085, phi=-2.310, mass=7.874)]
# done
# processed 80 events
# done
# [PseudoJet(pt=34.949, eta=-1.446, phi=2.706, mass=6.627)]
# done
# done
# [PseudoJet(pt=556.048, eta=-0.371, phi=-2.619, mass=70.517), PseudoJet(pt=451.039, eta=1.063, phi=1.169, mass=95.601), PseudoJet(pt=159.563, eta=0.830, phi=-0.243, mass=19.814), PseudoJet(pt=142.064, eta=-0.484, phi=-1.332, mass=15.262), PseudoJet(pt=113.014, eta=-1.078, phi=0.273, mass=13.289)]
# done
# done
# [PseudoJet(pt=745.281, eta=0.542, phi=2.211, mass=111.888), PseudoJet(pt=498.061, eta=-0.733, phi=-1.556, mass=34.770), PseudoJet(pt=292.104, eta=-0.328, phi=-0.795, mass=35.157), PseudoJet(pt=288.650, eta=1.613, phi=0.443, mass=38.230)]
# done
# done
# [PseudoJet(pt=90.613, eta=3.952, phi=1.761, mass=20.922), PseudoJet(pt=89.256, eta=1.564, phi=-1.722, mass=13.935), PseudoJet(pt=34.239, eta=0.919, phi=-0.404, mass=8.160)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=5285.372, eta=0.217, phi=2.113, mass=629.414), PseudoJet(pt=5280.129, eta=-0.026, phi=-1.032, mass=74.884)]
# done
# done
# [PseudoJet(pt=586.121, eta=1.210, phi=-0.926, mass=71.288), PseudoJet(pt=523.253, eta=-1.286, phi=2.073, mass=96.729), PseudoJet(pt=83.886, eta=0.927, phi=-1.978, mass=11.343), PseudoJet(pt=68.903, eta=-2.657, phi=2.512, mass=23.994)]
# done
# done
# [PseudoJet(pt=1795.176, eta=-0.877, phi=-2.699, mass=45.482), PseudoJet(pt=1793.680, eta=1.035, phi=0.431, mass=63.894)]
# done
# done
# [PseudoJet(pt=1943.373, eta=0.163, phi=-2.163, mass=113.671), PseudoJet(pt=1934.726, eta=-0.947, phi=0.962, mass=81.523)]
# done
# done
# [PseudoJet(pt=72.340, eta=2.218, phi=2.757, mass=14.603), PseudoJet(pt=55.097, eta=1.279, phi=-0.232, mass=9.939)]
# done
# processed 90 events
# done
# [PseudoJet(pt=449.670, eta=0.810, phi=1.544, mass=37.631), PseudoJet(pt=443.193, eta=-0.375, phi=-1.568, mass=74.496)]
# done
# done
# [PseudoJet(pt=1801.394, eta=-0.041, phi=0.163, mass=56.057), PseudoJet(pt=1712.453, eta=-0.744, phi=-2.935, mass=90.722), PseudoJet(pt=119.833, eta=0.830, phi=2.704, mass=14.411)]
# done
# done
# [PseudoJet(pt=2215.755, eta=0.713, phi=-0.468, mass=71.336), PseudoJet(pt=2150.183, eta=-0.390, phi=2.666, mass=161.162), PseudoJet(pt=74.033, eta=0.688, phi=2.918, mass=16.717)]
# done
# done
# [PseudoJet(pt=3120.718, eta=-0.118, phi=0.179, mass=165.168), PseudoJet(pt=2762.322, eta=0.097, phi=-2.882, mass=219.188), PseudoJet(pt=188.818, eta=1.201, phi=2.872, mass=34.438), PseudoJet(pt=150.919, eta=-1.628, phi=2.311, mass=26.685), PseudoJet(pt=86.382, eta=-0.730, phi=-2.311, mass=22.711), PseudoJet(pt=83.437, eta=0.277, phi=1.614, mass=18.935), PseudoJet(pt=55.067, eta=-0.414, phi=2.684, mass=14.293), PseudoJet(pt=48.311, eta=-3.287, phi=-0.936, mass=23.506), PseudoJet(pt=36.683, eta=1.146, phi=-2.417, mass=7.930)]
# done
# done
# []
# done
# done
# [PseudoJet(pt=2325.220, eta=0.360, phi=0.641, mass=71.143), PseudoJet(pt=2273.052, eta=0.795, phi=-2.426, mass=68.637), PseudoJet(pt=170.381, eta=1.195, phi=2.600, mass=24.259)]
# done
# done
# [PseudoJet(pt=1342.317, eta=0.695, phi=1.973, mass=120.674), PseudoJet(pt=1299.555, eta=-0.721, phi=-1.182, mass=113.136), PseudoJet(pt=34.986, eta=0.680, phi=-0.440, mass=10.993)]
# done
# done
# [PseudoJet(pt=123.684, eta=0.642, phi=-2.946, mass=43.314), PseudoJet(pt=123.130, eta=-1.820, phi=0.205, mass=17.029)]
# done
# done
# [PseudoJet(pt=1006.084, eta=0.883, phi=1.267, mass=49.268), PseudoJet(pt=989.827, eta=0.310, phi=-1.750, mass=33.397), PseudoJet(pt=121.094, eta=0.917, phi=2.778, mass=27.742)]
# done
